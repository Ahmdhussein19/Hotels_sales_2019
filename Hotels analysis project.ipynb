# %%
import pandas as pd

# %%
pd.read_csv('Hotels.csv')
# Out:
#              Code                                         Hotel Name  \
# 0      CODE|87851  Best Western Premier Al Ahsa Grand Hotel & Suites
# 1      CODE|87816   Best Western Premier Airporthotel Fontane Berlin
# 2      CODE|87781             Best Western Premier Agung Resort Ubud
# 3      CODE|87746                        Best Western Posada Freeman
# 4      CODE|87711             Best Western Pony Soldier Inn & Suites
# ...           ...                                                ...
# 22335         NaN                                                NaN
# 22336         NaN                                                NaN
# 22337         NaN                                                NaN
# 22338         NaN                                                NaN
# 22339         NaN                                                NaN
#
#        Roomnights    Sale    Cost      Date  Unnamed: 6  Unnamed: 7
# 0            57.0   1,140   1,140  01, 2019         NaN         NaN
# ...

# %%
df=pd.read_csv('Hotels.csv')

# %%
df
# Out:
#              Code                                         Hotel Name  \
# 0      CODE|87851  Best Western Premier Al Ahsa Grand Hotel & Suites
# 1      CODE|87816   Best Western Premier Airporthotel Fontane Berlin
# 2      CODE|87781             Best Western Premier Agung Resort Ubud
# 3      CODE|87746                        Best Western Posada Freeman
# 4      CODE|87711             Best Western Pony Soldier Inn & Suites
# ...           ...                                                ...
# 22335         NaN                                                NaN
# 22336         NaN                                                NaN
# 22337         NaN                                                NaN
# 22338         NaN                                                NaN
# 22339         NaN                                                NaN
#
#        Roomnights    Sale    Cost      Date  Unnamed: 6  Unnamed: 7
# 0            57.0   1,140   1,140  01, 2019         NaN         NaN
# ...

# %%
df=df.drop(columns=['Unnamed: 6', 'Unnamed: 7'])

# %%
df.dtypes
# Out:
# Code           object
# Hotel Name     object
# Roomnights    float64
# Sale           object
# Cost           object
# Date           object
# dtype: object

# %%
df.shape
# Out:
# (22340, 6)

# %%
df.isna().sum()
# Out:
# Code          19831
# Hotel Name    19831
# Roomnights    19831
# Sale          19831
# Cost          19831
# Date          19831
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 19839

# %%
df=df.dropna()

# %%
df.duplicated().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2504    False
# 2505    False
# 2506    False
# 2507    False
# 2508    False
# Length: 2509, dtype: bool>

# %%
df.duplicated().sum()
# Out:
# 9

# %%
df=df.drop_duplicates()

# %%
df.shape
# Out:
# (2500, 6)

# %%
df
# Out:
#             Code                                         Hotel Name  \
# 0     CODE|87851  Best Western Premier Al Ahsa Grand Hotel & Suites
# 1     CODE|87816   Best Western Premier Airporthotel Fontane Berlin
# 2     CODE|87781             Best Western Premier Agung Resort Ubud
# 3     CODE|87746                        Best Western Posada Freeman
# 4     CODE|87711             Best Western Pony Soldier Inn & Suites
# ...          ...                                                ...
# 2504    CODE|141                                Al Hail Waves Hotel
# 2505    CODE|106              Al Eairy Furnished Apartments Tabuk 6
# 2506     CODE|71                                   Al Bandar Rotana
# 2507     CODE|36           Aiden by Best Western @ Scottsdale North
# 2508      CODE|1                Adagio Aparthotel Jeddah Malik Road
#
#       Roomnights    Sale    Cost      Date
# 0           57.0   1,140   1,140  01, 2019
# 1         1935.0  50,310  38,700  08, 2019
# ...

# %%
df['Code'].str.split('|', expand=True)
# Out:
#          0      1
# 0     CODE  87851
# 1     CODE  87816
# 2     CODE  87781
# 3     CODE  87746
# 4     CODE  87711
# ...    ...    ...
# 2504  CODE    141
# 2505  CODE    106
# 2506  CODE     71
# 2507  CODE     36
# 2508  CODE      1
#
# [2500 rows x 2 columns]

# %%
code=df['Code'].str.split('|', expand=True)

# %%
#transforming the code column to be int. only
code.drop(columns=[0])
# Out:
#           1
# 0     87851
# 1     87816
# 2     87781
# 3     87746
# 4     87711
# ...     ...
# 2504    141
# 2505    106
# 2506     71
# 2507     36
# 2508      1
#
# [2500 rows x 1 columns]

# %%
code=code.drop(columns=[0])

# %%
code.rename(columns={1:'code'})
# Out:
#        code
# 0     87851
# 1     87816
# 2     87781
# 3     87746
# 4     87711
# ...     ...
# 2504    141
# 2505    106
# 2506     71
# 2507     36
# 2508      1
#
# [2500 rows x 1 columns]

# %%
code=code.rename(columns={1:'code'})

# %%
#adding to dataframe
df
# Out:
#             Code                                         Hotel Name  \
# 0     CODE|87851  Best Western Premier Al Ahsa Grand Hotel & Suites
# 1     CODE|87816   Best Western Premier Airporthotel Fontane Berlin
# 2     CODE|87781             Best Western Premier Agung Resort Ubud
# 3     CODE|87746                        Best Western Posada Freeman
# 4     CODE|87711             Best Western Pony Soldier Inn & Suites
# ...          ...                                                ...
# 2504    CODE|141                                Al Hail Waves Hotel
# 2505    CODE|106              Al Eairy Furnished Apartments Tabuk 6
# 2506     CODE|71                                   Al Bandar Rotana
# 2507     CODE|36           Aiden by Best Western @ Scottsdale North
# 2508      CODE|1                Adagio Aparthotel Jeddah Malik Road
#
#       Roomnights    Sale    Cost      Date
# 0           57.0   1,140   1,140  01, 2019
# 1         1935.0  50,310  38,700  08, 2019
# ...

# %%
df['code']= code

# %%
df['Code']= code

# %%
df
# Out:
#        Code                                         Hotel Name  Roomnights  \
# 0     87851  Best Western Premier Al Ahsa Grand Hotel & Suites        57.0
# 1     87816   Best Western Premier Airporthotel Fontane Berlin      1935.0
# 2     87781             Best Western Premier Agung Resort Ubud      1897.0
# 3     87746                        Best Western Posada Freeman      1294.0
# 4     87711             Best Western Pony Soldier Inn & Suites       828.0
# ...     ...                                                ...         ...
# 2504    141                                Al Hail Waves Hotel        31.0
# 2505    106              Al Eairy Furnished Apartments Tabuk 6      1097.0
# 2506     71                                   Al Bandar Rotana        29.0
# 2507     36           Aiden by Best Western @ Scottsdale North       495.0
# 2508      1                Adagio Aparthotel Jeddah Malik Road      1033.0
#
#         Sale    Cost      Date   code
# ...

# %%
df.drop(columns=['code'])
# Out:
#        Code                                         Hotel Name  Roomnights  \
# 0     87851  Best Western Premier Al Ahsa Grand Hotel & Suites        57.0
# 1     87816   Best Western Premier Airporthotel Fontane Berlin      1935.0
# 2     87781             Best Western Premier Agung Resort Ubud      1897.0
# 3     87746                        Best Western Posada Freeman      1294.0
# 4     87711             Best Western Pony Soldier Inn & Suites       828.0
# ...     ...                                                ...         ...
# 2504    141                                Al Hail Waves Hotel        31.0
# 2505    106              Al Eairy Furnished Apartments Tabuk 6      1097.0
# 2506     71                                   Al Bandar Rotana        29.0
# 2507     36           Aiden by Best Western @ Scottsdale North       495.0
# 2508      1                Adagio Aparthotel Jeddah Malik Road      1033.0
#
#         Sale    Cost      Date
# 0      1,140   1,140  01, 2019
# ...

# %%
df=df.drop(columns=['code'])

# %%
df
# Out:
#        Code                                         Hotel Name  Roomnights  \
# 0     87851  Best Western Premier Al Ahsa Grand Hotel & Suites        57.0
# 1     87816   Best Western Premier Airporthotel Fontane Berlin      1935.0
# 2     87781             Best Western Premier Agung Resort Ubud      1897.0
# 3     87746                        Best Western Posada Freeman      1294.0
# 4     87711             Best Western Pony Soldier Inn & Suites       828.0
# ...     ...                                                ...         ...
# 2504    141                                Al Hail Waves Hotel        31.0
# 2505    106              Al Eairy Furnished Apartments Tabuk 6      1097.0
# 2506     71                                   Al Bandar Rotana        29.0
# 2507     36           Aiden by Best Western @ Scottsdale North       495.0
# 2508      1                Adagio Aparthotel Jeddah Malik Road      1033.0
#
#         Sale    Cost      Date
# 0      1,140   1,140  01, 2019
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# Code           object
# Hotel Name     object
# Roomnights    float64
# Sale           object
# Cost           object
# Date           object
# dtype: object

# %%
df['Hotel Name'].str.replace('@', 'at')
# Out:
# 0       Best Western Premier Al Ahsa Grand Hotel & Suites
# 1        Best Western Premier Airporthotel Fontane Berlin
# 2                  Best Western Premier Agung Resort Ubud
# 3                             Best Western Posada Freeman
# 4                  Best Western Pony Soldier Inn & Suites
#                               ...
# 2504                                  Al Hail Waves Hotel
# 2505                Al Eairy Furnished Apartments Tabuk 6
# 2506                                     Al Bandar Rotana
# 2507            Aiden by Best Western at Scottsdale North
# 2508                  Adagio Aparthotel Jeddah Malik Road
# Name: Hotel Name, Length: 2500, dtype: object

# %%
df['Hotel Name']=df['Hotel Name'].str.replace('@', 'at')

# %%
df['Hotel Name'].str.upper()
# Out:
# 0       BEST WESTERN PREMIER AL AHSA GRAND HOTEL & SUITES
# 1        BEST WESTERN PREMIER AIRPORTHOTEL FONTANE BERLIN
# 2                  BEST WESTERN PREMIER AGUNG RESORT UBUD
# 3                             BEST WESTERN POSADA FREEMAN
# 4                  BEST WESTERN PONY SOLDIER INN & SUITES
#                               ...
# 2504                                  AL HAIL WAVES HOTEL
# 2505                AL EAIRY FURNISHED APARTMENTS TABUK 6
# 2506                                     AL BANDAR ROTANA
# 2507            AIDEN BY BEST WESTERN AT SCOTTSDALE NORTH
# 2508                  ADAGIO APARTHOTEL JEDDAH MALIK ROAD
# Name: Hotel Name, Length: 2500, dtype: object

# %%
df['Hotel Name']=df['Hotel Name'].str.upper()

# %%
df.columns
# Out:
# Index(['Code', 'Hotel Name', 'Roomnights', 'Sale', 'Cost', 'Date'], dtype='object')

# %%
df['Sale']=df['Sale'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 df['Sale']=df['Sale'].astype(int)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
#     447 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# ...

# %%
df['Sale']=df['Sale'].str.replace(',', '')

# %%
df['Sale']=df['Sale'].astype(int)

# %%
df['Cost']=df['Cost'].str.replace(',', '')

# %%
df['Cost']=df['Cost'].astype(int)

# %%
df.dtypes
# Out:
# Code           object
# Hotel Name     object
# Roomnights    float64
# Sale            int32
# Cost            int32
# Date           object
# dtype: object

# %%
pd.to_datetime(df['Date'])
# Out:
# 0      2019-01-01
# 1      2019-08-01
# 2      2019-01-01
# 3      2019-06-01
# 4      2019-12-01
#           ...
# 2504   2019-01-01
# 2505   2019-04-01
# 2506   2019-11-01
# 2507   2019-09-01
# 2508   2019-04-01
# Name: Date, Length: 2500, dtype: datetime64[ns]

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df['Code']=df['Code'].astype(int)

# %%
df.dtypes
# Out:
# Code                   int32
# Hotel Name            object
# Roomnights           float64
# Sale                   int32
# Cost                   int32
# Date          datetime64[ns]
# dtype: object

# %%
df
# Out:
#        Code                                         Hotel Name  Roomnights  \
# 0     87851  BEST WESTERN PREMIER AL AHSA GRAND HOTEL & SUITES        57.0
# 1     87816   BEST WESTERN PREMIER AIRPORTHOTEL FONTANE BERLIN      1935.0
# 2     87781             BEST WESTERN PREMIER AGUNG RESORT UBUD      1897.0
# 3     87746                        BEST WESTERN POSADA FREEMAN      1294.0
# 4     87711             BEST WESTERN PONY SOLDIER INN & SUITES       828.0
# ...     ...                                                ...         ...
# 2504    141                                AL HAIL WAVES HOTEL        31.0
# 2505    106              AL EAIRY FURNISHED APARTMENTS TABUK 6      1097.0
# 2506     71                                   AL BANDAR ROTANA        29.0
# 2507     36          AIDEN BY BEST WESTERN AT SCOTTSDALE NORTH       495.0
# 2508      1                ADAGIO APARTHOTEL JEDDAH MALIK ROAD      1033.0
#
#        Sale   Cost       Date
# 0      1140   1140 2019-01-01
# ...

# %%
df['Roomnights']=df['Roomnights'].astype(int)

# %%
df
# Out:
#        Code                                         Hotel Name  Roomnights  \
# 0     87851  BEST WESTERN PREMIER AL AHSA GRAND HOTEL & SUITES          57
# 1     87816   BEST WESTERN PREMIER AIRPORTHOTEL FONTANE BERLIN        1935
# 2     87781             BEST WESTERN PREMIER AGUNG RESORT UBUD        1897
# 3     87746                        BEST WESTERN POSADA FREEMAN        1294
# 4     87711             BEST WESTERN PONY SOLDIER INN & SUITES         828
# ...     ...                                                ...         ...
# 2504    141                                AL HAIL WAVES HOTEL          31
# 2505    106              AL EAIRY FURNISHED APARTMENTS TABUK 6        1097
# 2506     71                                   AL BANDAR ROTANA          29
# 2507     36          AIDEN BY BEST WESTERN AT SCOTTSDALE NORTH         495
# 2508      1                ADAGIO APARTHOTEL JEDDAH MALIK ROAD        1033
#
#        Sale   Cost       Date
# 0      1140   1140 2019-01-01
# ...

# %%
df.to_csv('hotels_final.csv')

# %%
pd.read_csv('Hotels Areas.csv')
# Out:
#         Hotel ID       Country  Unnamed: 2  Unnamed: 3
# 0      CODE|9976         Spain         NaN         NaN
# 1      CODE|9941         Chile         NaN         NaN
# 2      CODE|9906      Colombia         NaN         NaN
# 3      CODE|9871        Mexico         NaN         NaN
# 4      CODE|9836         Spain         NaN         NaN
# ...          ...           ...         ...         ...
# 2494  CODE|10116         Spain         NaN         NaN
# 2495  CODE|10081         Spain         NaN         NaN
# 2496  CODE|10046         Spain         NaN         NaN
# 2497  CODE|10011         Spain         NaN         NaN
# 2498      CODE|1  Saudi Arabia         NaN         NaN
#
# [2499 rows x 4 columns]

# %%
df2=pd.read_csv('Hotels Areas.csv')

# %%
df2
# Out:
#         Hotel ID       Country  Unnamed: 2  Unnamed: 3
# 0      CODE|9976         Spain         NaN         NaN
# 1      CODE|9941         Chile         NaN         NaN
# 2      CODE|9906      Colombia         NaN         NaN
# 3      CODE|9871        Mexico         NaN         NaN
# 4      CODE|9836         Spain         NaN         NaN
# ...          ...           ...         ...         ...
# 2494  CODE|10116         Spain         NaN         NaN
# 2495  CODE|10081         Spain         NaN         NaN
# 2496  CODE|10046         Spain         NaN         NaN
# 2497  CODE|10011         Spain         NaN         NaN
# 2498      CODE|1  Saudi Arabia         NaN         NaN
#
# [2499 rows x 4 columns]

# %%
df2.drop(columns=['Unnamed: 2','Unnamed: 3'])
# Out:
#         Hotel ID       Country
# 0      CODE|9976         Spain
# 1      CODE|9941         Chile
# 2      CODE|9906      Colombia
# 3      CODE|9871        Mexico
# 4      CODE|9836         Spain
# ...          ...           ...
# 2494  CODE|10116         Spain
# 2495  CODE|10081         Spain
# 2496  CODE|10046         Spain
# 2497  CODE|10011         Spain
# 2498      CODE|1  Saudi Arabia
#
# [2499 rows x 2 columns]

# %%
df2=df2.drop(columns=['Unnamed: 2','Unnamed: 3'])

# %%
df2.duplicated().sum()
# Out:
# 9

# %%
df2[df2.duplicated()]
# Out:
#        Hotel ID   Country
# 14    CODE|9556    France
# 16    CODE|9521     Spain
# 18    CODE|9486     Spain
# 20     CODE|946  Thailand
# 68   CODE|86766       USA
# 70   CODE|86731    France
# 72   CODE|86696       USA
# 214  CODE|82251     Italy
# 216  CODE|82216       USA

# %%
df2=df2.drop_duplicates()

# %%
df2.shape
# Out:
# (2490, 2)

# %%
hotel_id=df2['Hotel ID'].str.split('|', expand=True)

# %%
hotel_id
# Out:
#          0      1
# 0     CODE   9976
# 1     CODE   9941
# 2     CODE   9906
# 3     CODE   9871
# 4     CODE   9836
# ...    ...    ...
# 2494  CODE  10116
# 2495  CODE  10081
# 2496  CODE  10046
# 2497  CODE  10011
# 2498  CODE      1
#
# [2490 rows x 2 columns]

# %%
hotel_id.drop(columns=[0])
# Out:
#           1
# 0      9976
# 1      9941
# 2      9906
# 3      9871
# 4      9836
# ...     ...
# 2494  10116
# 2495  10081
# 2496  10046
# 2497  10011
# 2498      1
#
# [2490 rows x 1 columns]

# %%
hotel_id=hotel_id.drop(columns=[0])

# %%
hotel_id
# Out:
#           1
# 0      9976
# 1      9941
# 2      9906
# 3      9871
# 4      9836
# ...     ...
# 2494  10116
# 2495  10081
# 2496  10046
# 2497  10011
# 2498      1
#
# [2490 rows x 1 columns]

# %%
hotel_id.rename(columns={1:'hotel_id'})
# Out:
#      hotel_id
# 0        9976
# 1        9941
# 2        9906
# 3        9871
# 4        9836
# ...       ...
# 2494    10116
# 2495    10081
# 2496    10046
# 2497    10011
# 2498        1
#
# [2490 rows x 1 columns]

# %%
hotel_id=hotel_id.rename(columns={1:'hotel_id'})

# %%
hotel_id
# Out:
#      hotel_id
# 0        9976
# 1        9941
# 2        9906
# 3        9871
# 4        9836
# ...       ...
# 2494    10116
# 2495    10081
# 2496    10046
# 2497    10011
# 2498        1
#
# [2490 rows x 1 columns]

# %%
df2
# Out:
#         Hotel ID       Country
# 0      CODE|9976         Spain
# 1      CODE|9941         Chile
# 2      CODE|9906      Colombia
# 3      CODE|9871        Mexico
# 4      CODE|9836         Spain
# ...          ...           ...
# 2494  CODE|10116         Spain
# 2495  CODE|10081         Spain
# 2496  CODE|10046         Spain
# 2497  CODE|10011         Spain
# 2498      CODE|1  Saudi Arabia
#
# [2490 rows x 2 columns]

# %%
df['Hotel ID']= hotel_id

# %%
df=df.drop(columns=['Hotel ID'])

# %%
df
# Out:
#        Code                                         Hotel Name  Roomnights  \
# 0     87851  BEST WESTERN PREMIER AL AHSA GRAND HOTEL & SUITES          57
# 1     87816   BEST WESTERN PREMIER AIRPORTHOTEL FONTANE BERLIN        1935
# 2     87781             BEST WESTERN PREMIER AGUNG RESORT UBUD        1897
# 3     87746                        BEST WESTERN POSADA FREEMAN        1294
# 4     87711             BEST WESTERN PONY SOLDIER INN & SUITES         828
# ...     ...                                                ...         ...
# 2504    141                                AL HAIL WAVES HOTEL          31
# 2505    106              AL EAIRY FURNISHED APARTMENTS TABUK 6        1097
# 2506     71                                   AL BANDAR ROTANA          29
# 2507     36          AIDEN BY BEST WESTERN AT SCOTTSDALE NORTH         495
# 2508      1                ADAGIO APARTHOTEL JEDDAH MALIK ROAD        1033
#
#        Sale   Cost       Date
# 0      1140   1140 2019-01-01
# ...

# %%
df2['Hotel ID']= hotel_id
# Out:
# C:\Users\Ahmed\AppData\Local\Temp\ipykernel_26568\1047702679.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Hotel ID']= hotel_id

# %%
df2
# Out:
#      Hotel ID       Country
# 0        9976         Spain
# 1        9941         Chile
# 2        9906      Colombia
# 3        9871        Mexico
# 4        9836         Spain
# ...       ...           ...
# 2494    10116         Spain
# 2495    10081         Spain
# 2496    10046         Spain
# 2497    10011         Spain
# 2498        1  Saudi Arabia
#
# [2490 rows x 2 columns]

# %%
df2.rename(columns={'Hotel ID' : 'hotel_id'})
# Out:
#      hotel_id       Country
# 0        9976         Spain
# 1        9941         Chile
# 2        9906      Colombia
# 3        9871        Mexico
# 4        9836         Spain
# ...       ...           ...
# 2494    10116         Spain
# 2495    10081         Spain
# 2496    10046         Spain
# 2497    10011         Spain
# 2498        1  Saudi Arabia
#
# [2490 rows x 2 columns]

# %%
df2['Hotel ID']=df2.rename(columns={'Hotel ID' : 'hotel_id'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 df2['Hotel ID']=df2.rename(columns={'Hotel ID' : 'hotel_id'})
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3970, in DataFrame.__setitem__(self, key, value)
#    3968     self._setitem_array(key, value)
#    3969 elif isinstance(value, DataFrame):
# -> 3970     self._set_item_frame_value(key, value)
#    3971 elif (
#    3972     is_list_like(value)
#    3973     and not self.columns.is_unique
#    3974     and 1 < len(self.columns.get_indexer_for([key])) == len(value)
#    3975 ):
#    3976     # Column to set is duplicated
#    3977     self._setitem_array([key], value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4100, in DataFrame._set_item_frame_value(self, key, value)
#    4098 len_cols = 1 if is_scalar(cols) else len(cols)
# ...

# %%
df2=df2.rename(columns={'Hotel ID' : 'hotel_id'})

# %%
df2
# Out:
#      hotel_id       Country
# 0        9976         Spain
# 1        9941         Chile
# 2        9906      Colombia
# 3        9871        Mexico
# 4        9836         Spain
# ...       ...           ...
# 2494    10116         Spain
# 2495    10081         Spain
# 2496    10046         Spain
# 2497    10011         Spain
# 2498        1  Saudi Arabia
#
# [2490 rows x 2 columns]

# %%
df2.to_csv('hotel_id.csv')

# %%
df.to_csv('hotels_final1.csv', index=False)

# %%
df2.to_csv('hotel_id1.csv', index=False)

# %%
df
# Out:
#        Code                                         Hotel Name  Roomnights  \
# 0     87851  BEST WESTERN PREMIER AL AHSA GRAND HOTEL & SUITES          57
# 1     87816   BEST WESTERN PREMIER AIRPORTHOTEL FONTANE BERLIN        1935
# 2     87781             BEST WESTERN PREMIER AGUNG RESORT UBUD        1897
# 3     87746                        BEST WESTERN POSADA FREEMAN        1294
# 4     87711             BEST WESTERN PONY SOLDIER INN & SUITES         828
# ...     ...                                                ...         ...
# 2504    141                                AL HAIL WAVES HOTEL          31
# 2505    106              AL EAIRY FURNISHED APARTMENTS TABUK 6        1097
# 2506     71                                   AL BANDAR ROTANA          29
# 2507     36          AIDEN BY BEST WESTERN AT SCOTTSDALE NORTH         495
# 2508      1                ADAGIO APARTHOTEL JEDDAH MALIK ROAD        1033
#
#        Sale   Cost       Date
# 0      1140   1140 2019-01-01
# ...

# %%
df=df.rename(columns={'Code':'hotel_id'})

# %%
df
# Out:
#       hotel_id                                         Hotel Name  Roomnights  \
# 0        87851  BEST WESTERN PREMIER AL AHSA GRAND HOTEL & SUITES          57
# 1        87816   BEST WESTERN PREMIER AIRPORTHOTEL FONTANE BERLIN        1935
# 2        87781             BEST WESTERN PREMIER AGUNG RESORT UBUD        1897
# 3        87746                        BEST WESTERN POSADA FREEMAN        1294
# 4        87711             BEST WESTERN PONY SOLDIER INN & SUITES         828
# ...        ...                                                ...         ...
# 2504       141                                AL HAIL WAVES HOTEL          31
# 2505       106              AL EAIRY FURNISHED APARTMENTS TABUK 6        1097
# 2506        71                                   AL BANDAR ROTANA          29
# 2507        36          AIDEN BY BEST WESTERN AT SCOTTSDALE NORTH         495
# 2508         1                ADAGIO APARTHOTEL JEDDAH MALIK ROAD        1033
#
#        Sale   Cost       Date
# ...

# %%
df2
# Out:
#      hotel_id       Country
# 0        9976         Spain
# 1        9941         Chile
# 2        9906      Colombia
# 3        9871        Mexico
# 4        9836         Spain
# ...       ...           ...
# 2494    10116         Spain
# 2495    10081         Spain
# 2496    10046         Spain
# 2497    10011         Spain
# 2498        1  Saudi Arabia
#
# [2490 rows x 2 columns]

# %%
#merging 2 tables on hotel_id
df.merge(df2, on='hotel_id')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[97], line 2
#       1 #merging 2 tables on hotel_id
# ----> 2 df.merge(df2, on='hotel_id')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10093, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10074 @Substitution("")
#   10075 @Appender(_merge_doc, indents=2)
#   10076 def merge(
#    (...)
#   10089     validate: str | None = None,
#   10090 ) -> DataFrame:
#   10091     from pandas.core.reshape.merge import merge
# > 10093     return merge(
#   10094         self,
#   10095         right,
#   10096         how=how,
#   10097         on=on,
#   10098         left_on=left_on,
#   10099         right_on=right_on,
#   10100         left_index=left_index,
#   10101         right_index=right_index,
#   10102         sort=sort,
# ...

# %%
df2.dtypes
# Out:
# hotel_id    object
# Country     object
# dtype: object

# %%
df2['hotel_id'].astype(int)
# Out:
# 0        9976
# 1        9941
# 2        9906
# 3        9871
# 4        9836
#         ...
# 2494    10116
# 2495    10081
# 2496    10046
# 2497    10011
# 2498        1
# Name: hotel_id, Length: 2490, dtype: int32

# %%
df2['hotel_id']=df2['hotel_id'].astype(int)

# %%
df.merge(df2,on='hotel_id')
# Out:
#       hotel_id                                         Hotel Name  Roomnights  \
# 0        87851  BEST WESTERN PREMIER AL AHSA GRAND HOTEL & SUITES          57
# 1        87816   BEST WESTERN PREMIER AIRPORTHOTEL FONTANE BERLIN        1935
# 2        87781             BEST WESTERN PREMIER AGUNG RESORT UBUD        1897
# 3        87746                        BEST WESTERN POSADA FREEMAN        1294
# 4        87711             BEST WESTERN PONY SOLDIER INN & SUITES         828
# ...        ...                                                ...         ...
# 2485       141                                AL HAIL WAVES HOTEL          31
# 2486       106              AL EAIRY FURNISHED APARTMENTS TABUK 6        1097
# 2487        71                                   AL BANDAR ROTANA          29
# 2488        36          AIDEN BY BEST WESTERN AT SCOTTSDALE NORTH         495
# 2489         1                ADAGIO APARTHOTEL JEDDAH MALIK ROAD        1033
#
# ...

# %%
data=df.merge(df2,on='hotel_id')

# %%
data
# Out:
#       hotel_id                                         Hotel Name  Roomnights  \
# 0        87851  BEST WESTERN PREMIER AL AHSA GRAND HOTEL & SUITES          57
# 1        87816   BEST WESTERN PREMIER AIRPORTHOTEL FONTANE BERLIN        1935
# 2        87781             BEST WESTERN PREMIER AGUNG RESORT UBUD        1897
# 3        87746                        BEST WESTERN POSADA FREEMAN        1294
# 4        87711             BEST WESTERN PONY SOLDIER INN & SUITES         828
# ...        ...                                                ...         ...
# 2485       141                                AL HAIL WAVES HOTEL          31
# 2486       106              AL EAIRY FURNISHED APARTMENTS TABUK 6        1097
# 2487        71                                   AL BANDAR ROTANA          29
# 2488        36          AIDEN BY BEST WESTERN AT SCOTTSDALE NORTH         495
# 2489         1                ADAGIO APARTHOTEL JEDDAH MALIK ROAD        1033
#
# ...

# %%
data.isnull().sum()
# Out:
# hotel_id      0
# Hotel Name    0
# Roomnights    0
# Sale          0
# Cost          0
# Date          0
# Country       0
# dtype: int64

# %%
#to get profit
#profit = sale - cost
data['Sale']-data['Cost']
# Out:
# 0           0
# 1       11610
# 2        3794
# 3       12940
# 4        9108
#         ...
# 2485       93
# 2486     4388
# 2487      203
# 2488     5940
# 2489     7231
# Length: 2490, dtype: int32

# %%
profit=data['Sale']-data['Cost']

# %%
data['profit']= profit

# %%
data
# Out:
#       hotel_id                                         Hotel Name  Roomnights  \
# 0        87851  BEST WESTERN PREMIER AL AHSA GRAND HOTEL & SUITES          57
# 1        87816   BEST WESTERN PREMIER AIRPORTHOTEL FONTANE BERLIN        1935
# 2        87781             BEST WESTERN PREMIER AGUNG RESORT UBUD        1897
# 3        87746                        BEST WESTERN POSADA FREEMAN        1294
# 4        87711             BEST WESTERN PONY SOLDIER INN & SUITES         828
# ...        ...                                                ...         ...
# 2485       141                                AL HAIL WAVES HOTEL          31
# 2486       106              AL EAIRY FURNISHED APARTMENTS TABUK 6        1097
# 2487        71                                   AL BANDAR ROTANA          29
# 2488        36          AIDEN BY BEST WESTERN AT SCOTTSDALE NORTH         495
# 2489         1                ADAGIO APARTHOTEL JEDDAH MALIK ROAD        1033
#
# ...

# %%
#to get total profit for each country
data.groupby(['Country'])['profit'].sum()
# Out:
# Country
# Albania                   8110
# Algeria                  29372
# Andorra                  13540
# Argentina                60609
# Armenia                  60177
#                          ...
# Ukraine                   2256
# United Arab Emirates    868775
# United Kingdom          448162
# Vietnam                  23152
# Zambia                    4452
# Name: profit, Length: 106, dtype: int32

# %%
data
# Out:
#       hotel_id                                         Hotel Name  Roomnights  \
# 0        87851  BEST WESTERN PREMIER AL AHSA GRAND HOTEL & SUITES          57
# 1        87816   BEST WESTERN PREMIER AIRPORTHOTEL FONTANE BERLIN        1935
# 2        87781             BEST WESTERN PREMIER AGUNG RESORT UBUD        1897
# 3        87746                        BEST WESTERN POSADA FREEMAN        1294
# 4        87711             BEST WESTERN PONY SOLDIER INN & SUITES         828
# ...        ...                                                ...         ...
# 2485       141                                AL HAIL WAVES HOTEL          31
# 2486       106              AL EAIRY FURNISHED APARTMENTS TABUK 6        1097
# 2487        71                                   AL BANDAR ROTANA          29
# 2488        36          AIDEN BY BEST WESTERN AT SCOTTSDALE NORTH         495
# 2489         1                ADAGIO APARTHOTEL JEDDAH MALIK ROAD        1033
#
# ...

# %%
data.groupby(['Country'],as_index=False).sum().drop(columns=['hotel_id'])
# Out:
# C:\Users\Ahmed\AppData\Local\Temp\ipykernel_26568\4150114630.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['Country'],as_index=False).sum().drop(columns=['hotel_id'])
#                   Country  Roomnights     Sale     Cost  profit
# 0                 Albania         811    21897    13787    8110
# 1                 Algeria        3960    97939    68567   29372
# 2                 Andorra        1354    39266    25726   13540
# 3               Argentina       10691   258250   197641   60609
# 4                 Armenia        8533   210914   150737   60177
# ..                    ...         ...      ...      ...     ...
# 101               Ukraine         564    11844     9588    2256
# 102  United Arab Emirates      118118  2923723  2054948  868775
# ...

# %%
total_sales=data.groupby(['Country'],as_index=False).sum().drop(columns=['hotel_id'])
# Out:
# C:\Users\Ahmed\AppData\Local\Temp\ipykernel_26568\600554756.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   total_sales=data.groupby(['Country'],as_index=False).sum().drop(columns=['hotel_id'])

# %%
total_sales.to_csv('totalsalesFinal.csv',index=False)

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
df=pd.read_csv('hotels_final1.csv')

# %%
df
# Out:
#        Code                                         Hotel Name  Roomnights  \
# 0     87851  BEST WESTERN PREMIER AL AHSA GRAND HOTEL & SUITES          57
# 1     87816   BEST WESTERN PREMIER AIRPORTHOTEL FONTANE BERLIN        1935
# 2     87781             BEST WESTERN PREMIER AGUNG RESORT UBUD        1897
# 3     87746                        BEST WESTERN POSADA FREEMAN        1294
# 4     87711             BEST WESTERN PONY SOLDIER INN & SUITES         828
# ...     ...                                                ...         ...
# 2485    141                                AL HAIL WAVES HOTEL          31
# 2486    106              AL EAIRY FURNISHED APARTMENTS TABUK 6        1097
# 2487     71                                   AL BANDAR ROTANA          29
# 2488     36          AIDEN BY BEST WESTERN AT SCOTTSDALE NORTH         495
# 2489      1                ADAGIO APARTHOTEL JEDDAH MALIK ROAD        1033
#
#        Sale   Cost       Date               country
# ...

# %%
#clustring roomnights into 3 demand categories [low, medium, high]
#max roomnights = 1999, max/3=666.67
df.loc[df['Roomnights']<=666.67, 'demand_category']='Low'

# %%
df
# Out:
#        Code                                         Hotel Name  Roomnights  \
# 0     87851  BEST WESTERN PREMIER AL AHSA GRAND HOTEL & SUITES          57
# 1     87816   BEST WESTERN PREMIER AIRPORTHOTEL FONTANE BERLIN        1935
# 2     87781             BEST WESTERN PREMIER AGUNG RESORT UBUD        1897
# 3     87746                        BEST WESTERN POSADA FREEMAN        1294
# 4     87711             BEST WESTERN PONY SOLDIER INN & SUITES         828
# ...     ...                                                ...         ...
# 2485    141                                AL HAIL WAVES HOTEL          31
# 2486    106              AL EAIRY FURNISHED APARTMENTS TABUK 6        1097
# 2487     71                                   AL BANDAR ROTANA          29
# 2488     36          AIDEN BY BEST WESTERN AT SCOTTSDALE NORTH         495
# 2489      1                ADAGIO APARTHOTEL JEDDAH MALIK ROAD        1033
#
#        Sale   Cost       Date               country demand_category
# ...

# %%
df.loc[(df['Roomnights']>666.67) & (df['Roomnights']<= 1334), 'demand_category']='Mid'

# %%
df
# Out:
#        Code                                         Hotel Name  Roomnights  \
# 0     87851  BEST WESTERN PREMIER AL AHSA GRAND HOTEL & SUITES          57
# 1     87816   BEST WESTERN PREMIER AIRPORTHOTEL FONTANE BERLIN        1935
# 2     87781             BEST WESTERN PREMIER AGUNG RESORT UBUD        1897
# 3     87746                        BEST WESTERN POSADA FREEMAN        1294
# 4     87711             BEST WESTERN PONY SOLDIER INN & SUITES         828
# ...     ...                                                ...         ...
# 2485    141                                AL HAIL WAVES HOTEL          31
# 2486    106              AL EAIRY FURNISHED APARTMENTS TABUK 6        1097
# 2487     71                                   AL BANDAR ROTANA          29
# 2488     36          AIDEN BY BEST WESTERN AT SCOTTSDALE NORTH         495
# 2489      1                ADAGIO APARTHOTEL JEDDAH MALIK ROAD        1033
#
#        Sale   Cost       Date               country demand_category
# ...

# %%
df.loc[(df['Roomnights']>1334) & (df['Roomnights']<= 2000), 'demand_category']='High'

# %%
df
# Out:
#        Code                                         Hotel Name  Roomnights  \
# 0     87851  BEST WESTERN PREMIER AL AHSA GRAND HOTEL & SUITES          57
# 1     87816   BEST WESTERN PREMIER AIRPORTHOTEL FONTANE BERLIN        1935
# 2     87781             BEST WESTERN PREMIER AGUNG RESORT UBUD        1897
# 3     87746                        BEST WESTERN POSADA FREEMAN        1294
# 4     87711             BEST WESTERN PONY SOLDIER INN & SUITES         828
# ...     ...                                                ...         ...
# 2485    141                                AL HAIL WAVES HOTEL          31
# 2486    106              AL EAIRY FURNISHED APARTMENTS TABUK 6        1097
# 2487     71                                   AL BANDAR ROTANA          29
# 2488     36          AIDEN BY BEST WESTERN AT SCOTTSDALE NORTH         495
# 2489      1                ADAGIO APARTHOTEL JEDDAH MALIK ROAD        1033
#
#        Sale   Cost       Date               country demand_category
# ...

# %%
#Map countries into continents by pycountries library
import pycountry_convert as pc

# %%
def convert(row):
    cn_code = pc.country_name_to_country_alpha2(row.country, cn_name_format ='default')
    conti_code = pc.country_alpha2_to_continent_code(cn_code)
    return conti_code

# %%
df['continent']=df.apply(convert, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df['continent']=df.apply(convert, axis=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9568, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9557 from pandas.core.apply import frame_apply
#    9559 op = frame_apply(
#    9560     self,
#    9561     func=func,
#    (...)
#    9566     kwargs=kwargs,
#    9567 )
# -> 9568 return op.apply().__finalize__(self, method="apply")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:764, in FrameApply.apply(self)
#     761 elif self.raw:
#     762     return self.apply_raw()
# --> 764 return self.apply_standard()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:891, in FrameApply.apply_standard(self)
#     890 def apply_standard(self):
# ...

# %%
df[df['country']=='Turks And Caicos Island']
# Out:
#       Code                                    Hotel Name  Roomnights   Sale  \
# 594  66606  BEACHES TURKS & CAICOS RESORT VILLAGES & SPA        1453  34872
#
#       Cost       Date                  country demand_category
# 594  27607  10/1/2019  Turks And Caicos Island            High

# %%
df.loc[594,'country']
# Out:
# 'Turks And Caicos Island'

# %%
df.loc[594,'country']= 'Turks and Caicos Islands'

# %%
#convert again
df['continent']=df.apply(convert, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 2
#       1 #convert again
# ----> 2 df['continent']=df.apply(convert, axis=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9568, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9557 from pandas.core.apply import frame_apply
#    9559 op = frame_apply(
#    9560     self,
#    9561     func=func,
#    (...)
#    9566     kwargs=kwargs,
#    9567 )
# -> 9568 return op.apply().__finalize__(self, method="apply")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:764, in FrameApply.apply(self)
#     761 elif self.raw:
#     762     return self.apply_raw()
# --> 764 return self.apply_standard()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:891, in FrameApply.apply_standard(self)
#     890 def apply_standard(self):
# ...

# %%
df[df['country']=='Curacao']
# Out:
#        Code                          Hotel Name  Roomnights   Sale   Cost  \
# 2182  11026  ACOYA CURACAO RESORT, VILLAS & SPA        1736  43400  26040
#
#           Date  country demand_category
# 2182  3/1/2019  Curacao            High

# %%
df.loc[2182,'country']= 'Curaçao'

# %%
#converting again
df['continent']=df.apply(convert, axis=1)

# %%
df
# Out:
#        Code                                         Hotel Name  Roomnights  \
# 0     87851  BEST WESTERN PREMIER AL AHSA GRAND HOTEL & SUITES          57
# 1     87816   BEST WESTERN PREMIER AIRPORTHOTEL FONTANE BERLIN        1935
# 2     87781             BEST WESTERN PREMIER AGUNG RESORT UBUD        1897
# 3     87746                        BEST WESTERN POSADA FREEMAN        1294
# 4     87711             BEST WESTERN PONY SOLDIER INN & SUITES         828
# ...     ...                                                ...         ...
# 2485    141                                AL HAIL WAVES HOTEL          31
# 2486    106              AL EAIRY FURNISHED APARTMENTS TABUK 6        1097
# 2487     71                                   AL BANDAR ROTANA          29
# 2488     36          AIDEN BY BEST WESTERN AT SCOTTSDALE NORTH         495
# 2489      1                ADAGIO APARTHOTEL JEDDAH MALIK ROAD        1033
#
# ...

# %%
#mapping from codes to names
conti_names = { "AS":"Asia",
               "SA": "South America",
               "OC":"Oceania",
               "EU":"Europe",
               "NA":"North America",
               "AF": "Africa"}

df['continent'].map(conti_names)
#checking the code
# Out:
# 0                Asia
# 1              Europe
# 2                Asia
# 3       North America
# 4       North America
#             ...
# 2485             Asia
# 2486             Asia
# 2487             Asia
# 2488    North America
# 2489             Asia
# Name: continent, Length: 2490, dtype: object

# %%
#applying conversion
conti_names = { "AS":"Asia",
               "SA": "South America",
               "OC":"Oceania",
               "EU":"Europe",
               "NA":"North America",
               "AF": "Africa"}

df['continent']=df['continent'].map(conti_names)
df
# Out:
#        Code                                         Hotel Name  Roomnights  \
# 0     87851  BEST WESTERN PREMIER AL AHSA GRAND HOTEL & SUITES          57
# 1     87816   BEST WESTERN PREMIER AIRPORTHOTEL FONTANE BERLIN        1935
# 2     87781             BEST WESTERN PREMIER AGUNG RESORT UBUD        1897
# 3     87746                        BEST WESTERN POSADA FREEMAN        1294
# 4     87711             BEST WESTERN PONY SOLDIER INN & SUITES         828
# ...     ...                                                ...         ...
# 2485    141                                AL HAIL WAVES HOTEL          31
# 2486    106              AL EAIRY FURNISHED APARTMENTS TABUK 6        1097
# 2487     71                                   AL BANDAR ROTANA          29
# 2488     36          AIDEN BY BEST WESTERN AT SCOTTSDALE NORTH         495
# 2489      1                ADAGIO APARTHOTEL JEDDAH MALIK ROAD        1033
#
# ...

# %%
#getting profit 
profit=df['Sale']-df['Cost']
df['profit']=profit

# %%
df
# Out:
#        Code                                         Hotel Name  Roomnights  \
# 0     87851  BEST WESTERN PREMIER AL AHSA GRAND HOTEL & SUITES          57
# 1     87816   BEST WESTERN PREMIER AIRPORTHOTEL FONTANE BERLIN        1935
# 2     87781             BEST WESTERN PREMIER AGUNG RESORT UBUD        1897
# 3     87746                        BEST WESTERN POSADA FREEMAN        1294
# 4     87711             BEST WESTERN PONY SOLDIER INN & SUITES         828
# ...     ...                                                ...         ...
# 2485    141                                AL HAIL WAVES HOTEL          31
# 2486    106              AL EAIRY FURNISHED APARTMENTS TABUK 6        1097
# 2487     71                                   AL BANDAR ROTANA          29
# 2488     36          AIDEN BY BEST WESTERN AT SCOTTSDALE NORTH         495
# 2489      1                ADAGIO APARTHOTEL JEDDAH MALIK ROAD        1033
#
# ...

# %%
#group by continent
global_summary=df.groupby(['continent'], as_index=False).sum().drop(columns=['Code'])
# Out:
# C:\Users\Ahmed\AppData\Local\Temp\ipykernel_23116\920732027.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   global_summary=df.groupby(['continent'], as_index=False).sum().drop(columns=['Code'])

# %%
global_summary
# Out:
#        continent  Roomnights      Sale      Cost   profit
# 0         Africa      131007   3269792   2298483   971309
# 1           Asia      938213  23699988  16466584  7233404
# 2         Europe      987298  24610391  17318718  7291673
# 3  North America      381375   9533074   6665201  2867873
# 4        Oceania       23302    572183    417817   154366
# 5  South America       30334    740310    546156   194154

# %%
global_summary.to_csv('global_summary.csv')

# %%
df.to_csv('hotels_summary_19.csv', index=False)
